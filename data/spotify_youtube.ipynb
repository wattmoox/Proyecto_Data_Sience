# %%
import requests
import csv
import pandas as pd

# %%
def csv_a_diccionario(archivo_csv):

    with open(archivo_csv, 'r') as csvfile:
        lector = csv.DictReader(csvfile)
        lista_diccionarios = []
        for fila in lector:
            lista_diccionarios.append(fila)
        return lista_diccionarios

# %%
# Tu clave de API de YouTube

# Probar con estas si no les deja seguir
#API_KEY = 'AIzaSyAnGn-UXfoPNvYr_-aamiOkUUau1SET7pI'
#API_KEY = 'AIzaSyBO3CgUc8LyPI5E5hOBVGjTM5wU9Oc0cKE'
API_KEY = "AIzaSyDI0-A2UEHSWavIX8vSQGt4-2wvgYRO3DQ"

# Base URL de la API de YouTube para buscar videos
search_url = 'https://www.googleapis.com/youtube/v3/search'
video_url = 'https://www.googleapis.com/youtube/v3/videos'

diccionario = csv_a_diccionario('spotify_global.csv')
print(diccionario)

# %%
# Función para buscar el video de la canción en YouTube
def get_youtube_views(song_title, artist_name):
    # Realizamos la búsqueda en YouTube combinando título y artista
    query = f"{song_title} {artist_name}"
    search_params = {
        'part': 'snippet',
        'q': query,
        'type': 'video',
        'maxResults': 1,
        'videoCategoryId': '10',
        'order': 'viewCount',
        'key': API_KEY
    }
    search_response = requests.get(search_url, params=search_params)
    search_data = search_response.json()
    #print(search_data)


    #print(search_data)
    # Obtenemos el ID del primer video en los resultados de búsqueda
    video_id = search_data['items'][0]['id']['videoId']

    # Obtenemos las estadísticas del video usando el video ID
    video_params = {
        'part': 'snippet,statistics',
        'id': video_id,
        'key': API_KEY
    }
    video_response = requests.get(video_url, params=video_params)
    video_search = video_response.json()
    video = video_search["items"][0]

    title = video['snippet']['title']
    date = video['snippet']['publishedAt']
    views = video['statistics'].get('viewCount', 'N/A')
    likes = video['statistics'].get('likeCount', 'N/A')
    coments = video['statistics'].get('commentCount', 'N/A')

    descirpcion = video["snippet"]["description"].split(" ")
    tags = list(filter(lambda x: x.startswith("#"), descirpcion))

    print(f'Título: {title}, Artista: {artist}, Vistas: {views}, Likes: {likes}, Comentarios: {coments}, Fecha: {date}')
    return [title, views, likes, coments, date, tags]
    
# Extraer la información y crear listas
titles = []
artistas = []
visitas = []
me_gusta = []
comentarios = []
fechas = []
etiquetas = []
popularidades = []
generos = []

# Proceso para obtener las visitas de cada canción
for song in diccionario:
    title = song['Titulo']
    artist = song['Artista']
    popularidad = song['Popularidad']
    genero = song['Generos']

    title, views, likes, coments, date, tags = get_youtube_views(title, artist)

    titles.append(title)
    artistas.append(artist)
    visitas.append(int(views))

    if likes.isnumeric():
        me_gusta.append(int(likes))
    else:
        me_gusta.append(0)
    if coments.isnumeric():
        comentarios.append(int(coments))
    else:
        comentarios.append(0)
    fechas.append(date)
    etiquetas.append(tags)
    if popularidad.isnumeric():
        popularidades.append(int(popularidad))
    else:
        popularidades.append(0)
    generos.append(genero)

# %%
# Crear el archivo CSV
with open('videos_spotify_global.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Titulo', 'Artista', 'Vistas', 'Likes', 'Comentarios', 'Fecha', "Tags", "Popularidades", "Generos"])
    for row in zip(titles, artistas, visitas, me_gusta, comentarios, fechas, etiquetas, popularidades, generos):
        writer.writerow(row)

# %%
def csv_a_diccionario(archivo_csv):

    with open(archivo_csv, 'r') as csvfile:
        lector = csv.DictReader(csvfile)
        lista_diccionarios = []
        for fila in lector:
            lista_diccionarios.append(fila)
        return lista_diccionarios

# %%
# Tu clave de API de YouTube
# Probar con estas si no les deja seguir
#API_KEY = 'AIzaSyAnGn-UXfoPNvYr_-aamiOkUUau1SET7pI'
#API_KEY = 'AIzaSyBO3CgUc8LyPI5E5hOBVGjTM5wU9Oc0cKE'
API_KEY = "AIzaSyDI0-A2UEHSWavIX8vSQGt4-2wvgYRO3DQ"

# Base URL de la API de YouTube para buscar videos
search_url = 'https://www.googleapis.com/youtube/v3/search'
video_url = 'https://www.googleapis.com/youtube/v3/videos'

diccionario = csv_a_diccionario('spotify_global.csv')
print(diccionario)
# Out:
# [{'Titulo': 'That’s So True', 'Artista': 'Gracie Abrams', 'Popularidad': '91', 'Generos': "['alt z']"}, {'Titulo': 'Die With A Smile', 'Artista': 'Lady Gaga', 'Popularidad': '100', 'Generos': "['art pop', 'dance pop', 'pop']"}, {'Titulo': 'Sailor Song', 'Artista': 'Gigi Perez', 'Popularidad': '93', 'Generos': "['bedroom pop']"}, {'Titulo': 'Sticky (feat. GloRilla, Sexyy Red & Lil Wayne)', 'Artista': 'Tyler, The Creator', 'Popularidad': '87', 'Generos': "['hip hop', 'rap']"}, {'Titulo': 'St. Chroma (feat. Daniel Caesar)', 'Artista': 'Tyler, The Creator', 'Popularidad': '89', 'Generos': "['hip hop', 'rap']"}, {'Titulo': 'BIRDS OF A FEATHER', 'Artista': 'Billie Eilish', 'Popularidad': '97', 'Generos': "['art pop', 'pop']"}, {'Titulo': 'Who', 'Artista': 'Jimin', 'Popularidad': '92', 'Generos': "['k-pop']"}, {'Titulo': 'Taste', 'Artista': 'Sabrina Carpenter', 'Popularidad': '94', 'Generos': "['pop']"}, {'Titulo': 'APT.', 'Artista': 'ROSÉ', 'Popularidad': '97', 'Generos': "['k-pop']"}, {'Titulo': 'Timeless (with Playboi Carti)', 'Artista': 'The Weeknd', 'Popularidad': '92', 'Generos': "['canadian contemporary r&b', 'canadian pop', 'pop']"}, {'Titulo': 'Good Luck, Babe!', 'Artista': 'Chappell Roan', 'Popularidad': '94', 'Generos': "['indie pop']"}, {'Titulo': 'WILDFLOWER', 'Artista': 'Billie Eilish', 'Popularidad': '92', 'Generos': "['art pop', 'pop']"}, {'Titulo': 'See You Again (feat. Kali Uchis)', 'Artista': 'Tyler, The Creator', 'Popularidad': '89', 'Generos': "['hip hop', 'rap']"}, {'Titulo': "I Love You, I'm Sorry", 'Artista': 'Gracie Abrams', 'Popularidad': '90', 'Generos': "['alt z']"}, {'Titulo': 'Espresso', 'Artista': 'Sabrina Carpenter', 'Popularidad': '88', 'Generos': "['pop']"}, {'Titulo': 'Like Him (feat. Lola Young)', 'Artista': 'Tyler, The Creator', 'Popularidad': '85', 'Generos': "['hip hop', 'rap']"}, {'Titulo': 'Darling, I (feat. Teezo Touchdown)', 'Artista': 'Tyler, The Creator', 'Popularidad': '87', 'Generos': "['hip hop', 'rap']"}, {'Titulo': 'A Bar Song (Tipsy)', 'Artista': 'Shaboozey', 'Popularidad': '84', 'Generos': "['modern country pop', 'pop rap']"}, {'Titulo': 'Tu Boda', 'Artista': 'Oscar Maydon', 'Popularidad': '93', 'Generos': "['corrido']"}, {'Titulo': 'Love Somebody', 'Artista': 'Morgan Wallen', 'Popularidad': '85', 'Generos': "['contemporary country']"}, {'Titulo': 'I Had Some Help (Feat. Morgan Wallen)', 'Artista': 'Post Malone', 'Popularidad': '84', 'Generos': "['dfw rap', 'melodic rap', 'pop', 'rap']"}, {'Titulo': 'Rah Tah Tah', 'Artista': 'Tyler, The Creator', 'Popularidad': '87', 'Generos': "['hip hop', 'rap']"}, {'Titulo': 'Please Please Please', 'Artista': 'Sabrina Carpenter', 'Popularidad': '87', 'Generos': "['pop']"}, {'Titulo': 'HOT TO GO!', 'Artista': 'Chappell Roan', 'Popularidad': '89', 'Generos': "['indie pop']"}, {'Titulo': 'Beautiful Things', 'Artista': 'Benson Boone', 'Popularidad': '89', 'Generos': "['singer-songwriter pop']"}, {'Titulo': 'No One Noticed', 'Artista': 'The Marías', 'Popularidad': '83', 'Generos': "['bedroom pop', 'la indie']"}, {'Titulo': 'Bed Chem', 'Artista': 'Sabrina Carpenter', 'Popularidad': '91', 'Generos': "['pop']"}, {'Titulo': 'Pink Pony Club', 'Artista': 'Chappell Roan', 'Popularidad': '86', 'Generos': "['indie pop']"}, {'Titulo': 'Thought I Was Dead (feat. ScHoolboy Q & Santigold)', 'Artista': 'Tyler, The Creator', 'Popularidad': '85', 'Generos': "['hip hop', 'rap']"}, {'Titulo': 'Stick Season', 'Artista': 'Noah Kahan', 'Popularidad': '87', 'Generos': "['pov: indie', 'singer-songwriter pop']"}, {'Titulo': 'Sweater Weather', 'Artista': 'The Neighbourhood', 'Popularidad': '90', 'Generos': "['modern alternative rock', 'modern rock', 'pop']"}, {'Titulo': 'Lose Control', 'Artista': 'Teddy Swims', 'Popularidad': '89', 'Generos': '[]'}, {'Titulo': 'I Remember Everything (feat. Kacey Musgraves)', 'Artista': 'Zach Bryan', 'Popularidad': '86', 'Generos': "['classic oklahoma country']"}, {'Titulo': 'NIGHTS LIKE THIS', 'Artista': 'The Kid LAROI', 'Popularidad': '88',  ...

# %%
# Función para buscar el video de la canción en YouTube
def get_youtube_views(song_title, artist_name):
    # Realizamos la búsqueda en YouTube combinando título y artista
    query = f"{song_title} {artist_name}"
    search_params = {
        'part': 'snippet',
        'q': query,
        'type': 'video',
        'maxResults': 1,
        'videoCategoryId': '10',
        'order': 'viewCount',
        'key': API_KEY
    }
    search_response = requests.get(search_url, params=search_params)
    search_data = search_response.json()
    #print(search_data)


    #print(search_data)
    # Obtenemos el ID del primer video en los resultados de búsqueda
    video_id = search_data['items'][0]['id']['videoId']

    # Obtenemos las estadísticas del video usando el video ID
    video_params = {
        'part': 'snippet,statistics',
        'id': video_id,
        'key': API_KEY
    }
    video_response = requests.get(video_url, params=video_params)
    video_search = video_response.json()
    video = video_search["items"][0]

    title = video['snippet']['title']
    date = video['snippet']['publishedAt']
    views = video['statistics'].get('viewCount', 'N/A')
    likes = video['statistics'].get('likeCount', 'N/A')
    coments = video['statistics'].get('commentCount', 'N/A')

    descirpcion = video["snippet"]["description"].split(" ")
    tags = list(filter(lambda x: x.startswith("#"), descirpcion))

    print(f'Título: {title}, Artista: {artist}, Vistas: {views}, Likes: {likes}, Comentarios: {coments}, Fecha: {date}')
    return [title, views, likes, coments, date, tags]
    
# Extraer la información y crear listas
titles = []
artistas = []
visitas = []
me_gusta = []
comentarios = []
fechas = []
etiquetas = []
popularidades = []
generos = []

# Proceso para obtener las visitas de cada canción
for song in diccionario:
    title = song['Titulo']
    artist = song['Artista']
    popularidad = song['Popularidad']
    genero = song['Generos']

    title, views, likes, coments, date, tags = get_youtube_views(title, artist)

    titles.append(title)
    artistas.append(artist)
    visitas.append(int(views))

    if likes.isnumeric():
        me_gusta.append(int(likes))
    else:
        me_gusta.append(0)
    if coments.isnumeric():
        comentarios.append(int(coments))
    else:
        comentarios.append(0)
    fechas.append(date)
    etiquetas.append(tags)
    if popularidad.isnumeric():
        popularidades.append(int(popularidad))
    else:
        popularidades.append(0)
    generos.append(genero)
# Out:
# Título: Gracie Abrams - I miss you, I’m sorry (Lyric Video), Artista: Gracie Abrams, Vistas: 48018476, Likes: 1272215, Comentarios: 14226, Fecha: 2020-04-08T13:00:31Z
# Título: Lady Gaga, Bruno Mars - Die With A Smile (Official Music Video), Artista: Lady Gaga, Vistas: 287462068, Likes: 4608560, Comentarios: 128114, Fecha: 2024-08-16T04:00:36Z
# Título: Sailor Song, Artista: Gigi Perez, Vistas: 11078749, Likes: 178749, Comentarios: 1550, Fecha: 2024-09-23T23:12:05Z
# Título: GloRilla - WHATCHU KNO ABOUT ME ft. Sexyy Red (Official Music Video), Artista: Tyler, The Creator, Vistas: 14864892, Likes: 256594, Comentarios: 10401, Fecha: 2024-10-11T04:00:06Z
# Título: St. Chroma, Artista: Tyler, The Creator, Vistas: 10485435, Likes: 277131, Comentarios: 14121, Fecha: 2024-10-28T10:02:12Z
# Título: Billie Eilish, Khalid - lovely, Artista: Billie Eilish, Vistas: 2138326363, Likes: 27467850, Comentarios: 626681, Fecha: 2018-04-26T16:00:02Z
# Título: 지민 (Jimin) 'Set Me Free Pt.2' Official MV, Artista: Jimin, Vistas: 160154737, Likes: 5271907, Comentarios: 611995, Fecha: 2023-03-17T03:59:11Z
# Título: Sabrina Carpenter - Please Please Please (Official Video), Artista: Sabrina Carpenter, Vistas: 145985443, Likes: 2122427, Comentarios: 41995, Fecha: 2024-06-07T00:00:06Z
# Título: ROSÉ & Bruno Mars - APT. (Official Music Video), Artista: ROSÉ, Vistas: 333881853, Likes: 8657578, Comentarios: 395535, Fecha: 2024-10-18T04:00:07Z
# Título: Travis Scott - FE!N ft. Playboi Carti, Artista: The Weeknd, Vistas: 109090075, Likes: 1829217, Comentarios: 54966, Fecha: 2024-03-30T21:00:04Z
# Título: Good Luck, Babe!, Artista: Chappell Roan, Vistas: 56765969, Likes: 634734, Comentarios: 4119, Fecha: 2024-04-04T10:02:03Z
# Título: Billie Eilish, Khalid - lovely, Artista: Billie Eilish, Vistas: 2138326363, Likes: 27467850, Comentarios: 626681, Fecha: 2018-04-26T16:00:02Z
# Título: Wiz Khalifa - See You Again ft. Charlie Puth [Official Video] Furious 7 Soundtrack, Artista: Tyler, The Creator, Vistas: 6461372325, Likes: 44040460, Comentarios: 2257925, Fecha: 2015-04-07T03:00:03Z
